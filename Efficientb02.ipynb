# %% [markdown]
# <a href="https://colab.research.google.com/github/Krish6115/NNDL_PROJ/blob/main/Efficientb02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORTANT: RUN THIS CELL IN ORDER TO IMPORT YOUR KAGGLE DATA SOURCES,
# THEN FEEL FREE TO DELETE THIS CELL.
# NOTE: THIS NOTEBOOK ENVIRONMENT DIFFERS FROM KAGGLE'S PYTHON
# ENVIRONMENT SO THERE MAY BE MISSING LIBRARIES USED BY YOUR
# NOTEBOOK.
import kagglehub
vipoooool_new_plant_diseases_dataset_path = kagglehub.dataset_download('vipoooool/new-plant-diseases-dataset')

print('Data source import complete.')

# %%
import tensorflow as tf
from tensorflow.keras import layers, models, applications
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau # Using both callbacks
import matplotlib.pyplot as plt
import numpy as np
import os
import shutil
import seaborn as sns
from sklearn.metrics import classification_report, confusion_matrix

# 1. SETUP: CREATE FOCUSED "APPLE-ONLY" DATASET
# ==============================================================================
print("--- Setting up 'Apple-only' train, validation, and test datasets ---")

original_base_train_dir = '/kaggle/input/new-plant-diseases-dataset/New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)/train'
original_base_valid_dir = '/kaggle/input/new-plant-diseases-dataset/New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)/valid'

apple_classes = [
    'Apple___Apple_scab',
    'Apple___Black_rot',
    'Apple___Cedar_apple_rust',
    'Apple___healthy'
]

temp_base_dir = '/kaggle/working/apple_dataset'
train_dir = os.path.join(temp_base_dir, 'train')
validation_dir = os.path.join(temp_base_dir, 'valid')
test_dir = os.path.join(temp_base_dir, 'test')

os.makedirs(train_dir, exist_ok=True)
os.makedirs(validation_dir, exist_ok=True)
os.makedirs(test_dir, exist_ok=True)

for class_name in apple_classes:
    for original_dir, new_dir in [(original_base_train_dir, train_dir), (original_base_valid_dir, validation_dir), (original_base_valid_dir, test_dir)]:
        original_path = os.path.join(original_dir, class_name)
        new_path = os.path.join(new_dir, class_name)
        if not os.path.exists(new_path):
            os.symlink(original_path, new_path)

print(f"Dataset setup complete. Using data from: {temp_base_dir}")
print("----------------------------------------------------------------------")


# 2. DEFINE CONSTANTS AND HYPERPARAMETERS
# ==============================================================================
IMG_SIZE = 224
BATCH_SIZE = 32
# --- HYPERPARAMETERS FOR A GOOD FIT ---
DROPOUT_RATE = 0.5
INITIAL_EPOCHS = 10     # More epochs for the first stage to let LR scheduler work
FINE_TUNE_EPOCHS = 15   # More epochs for fine-tuning
TOTAL_EPOCHS = INITIAL_EPOCHS + FINE_TUNE_EPOCHS
INITIAL_LR = 0.001
FINE_TUNE_LR = 0.00001


# 3. LOAD AND PREPROCESS DATA
# ==============================================================================
train_ds = tf.keras.utils.image_dataset_from_directory(train_dir, image_size=(IMG_SIZE, IMG_SIZE), batch_size=BATCH_SIZE, shuffle=True, seed=123)
val_ds = tf.keras.utils.image_dataset_from_directory(validation_dir, image_size=(IMG_SIZE, IMG_SIZE), batch_size=BATCH_SIZE, shuffle=False)
test_ds = tf.keras.utils.image_dataset_from_directory(test_dir, image_size=(IMG_SIZE, IMG_SIZE), batch_size=BATCH_SIZE, shuffle=False)

class_names = train_ds.class_names
NUM_CLASSES = len(class_names)
print(f"Found {NUM_CLASSES} classes: {class_names}")

AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.cache().prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)
test_ds = test_ds.cache().prefetch(buffer_size=AUTOTUNE)


# 4. DEFINE THE EFFICIENTNETB0 MODEL
# ==============================================================================
data_augmentation = models.Sequential([layers.RandomFlip("horizontal_and_vertical"), layers.RandomRotation(0.2)], name="data_augmentation")

base_model = applications.EfficientNetB0(include_top=False, weights='imagenet', input_shape=(IMG_SIZE, IMG_SIZE, 3))
base_model.trainable = False

inputs = layers.Input(shape=(IMG_SIZE, IMG_SIZE, 3))
x = data_augmentation(inputs)
x = base_model(x, training=False)
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dropout(DROPOUT_RATE)(x)
outputs = layers.Dense(NUM_CLASSES, activation='softmax')(x)
model = models.Model(inputs, outputs, name="EfficientNetB0_FineTuned")

# 5. COMPILE AND TRAIN (TWO-STAGE PROCESS)
# ==============================================================================
# --- Stage 1: Initial Training with LR Scheduler ---
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=INITIAL_LR), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
lr_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=2, min_lr=1e-6, verbose=1)

print("\n--- Stage 1: Training Head with LR Scheduler ---")
history = model.fit(train_ds, epochs=INITIAL_EPOCHS, validation_data=val_ds, callbacks=[early_stopping, lr_scheduler])

# --- Stage 2: Fine-Tuning ---
base_model.trainable = True
for layer in base_model.layers[:-20]:
    layer.trainable = False

model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=FINE_TUNE_LR), loss='sparse_categorical_crossentropy', metrics=['accuracy'])
print("\n--- Stage 2: Fine-Tuning Body ---")
history_fine_tune = model.fit(train_ds, epochs=TOTAL_EPOCHS, initial_epoch=history.epoch[-1], validation_data=val_ds, callbacks=[early_stopping])

# 6. PLOT TRAINING & VALIDATION HISTORY
# ==============================================================================
def plot_fine_tune_history(history, history_fine):
    acc = history.history['accuracy'] + history_fine.history['accuracy']
    val_acc = history.history['val_accuracy'] + history_fine.history['val_accuracy']
    loss = history.history['loss'] + history_fine.history['loss']
    val_loss = history.history['val_loss'] + history_fine.history['val_loss']

    plt.style.use('seaborn-v0_8-whitegrid')
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(18, 6))

    ax1.plot(acc, 'o-', label='Train Accuracy')
    ax1.plot(val_acc, 'o--', label='Validation Accuracy')
    ax1.axvline(x=len(history.history['accuracy'])-1, color='gray', linestyle='--', label='Start of Fine-Tuning')
    ax1.set_title('Model Accuracy')
    ax1.set_ylabel('Accuracy')
    ax1.set_xlabel('Epoch')
    ax1.legend()

    ax2.plot(loss, 'o-', label='Train Loss')
    ax2.plot(val_loss, 'o--', label='Validation Loss')
    ax2.axvline(x=len(history.history['loss'])-1, color='gray', linestyle='--', label='Start of Fine-Tuning')
    ax2.set_title('Model Loss')
    ax2.set_ylabel('Loss')
    ax2.set_xlabel('Epoch')
    ax2.legend()
    plt.suptitle('Fine-Tuning Performance for EfficientNetB0', fontsize=16)
    plt.show()

plot_fine_tune_history(history, history_fine_tune)

# 7. FINAL EVALUATION AND CLASSIFICATION METRICS ON TEST SET
# ==============================================================================
print("\n--- Model Evaluation on Test Set ---")

loss, accuracy = model.evaluate(test_ds, verbose=1)
print(f"✅ Fine-Tuned EfficientNetB0 Test Accuracy: {accuracy*100:.2f}%")
print(f"✅ Fine-Tuned EfficientNetB0 Test Loss: {loss:.4f}")

print("\n--- Generating Classification Report and Confusion Matrix ---")
y_true = np.concatenate([y for x, y in test_ds], axis=0)
y_pred_probs = model.predict(test_ds)
y_pred = np.argmax(y_pred_probs, axis=1)

print("\nClassification Report:")
print(classification_report(y_true, y_pred, target_names=class_names))

print("\nConfusion Matrix:")
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.title('Confusion Matrix for Fine-Tuned EfficientNetB0')
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.show()
# Out:
# 2025-10-16 17:40:34.625608: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1760636434.891950      37 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1760636434.973541      37 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# --- Setting up 'Apple-only' train, validation, and test datasets ---
# Dataset setup complete. Using data from: /kaggle/working/apple_dataset
# ----------------------------------------------------------------------
# Found 7771 files belonging to 4 classes.
# I0000 00:00:1760636452.106401      37 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13942 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1760636452.107270      37 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13942 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Found 1943 files belonging to 4 classes.
# Found 1943 files belonging to 4 classes.
# Found 4 classes: ['Apple___Apple_scab', 'Apple___Black_rot', 'Apple___Cedar_apple_rust', 'Apple___healthy']
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
#
# --- Stage 1: Training Head with LR Scheduler ---
# Epoch 1/10
# E0000 00:00:1760636473.356109      37 meta_optimizer.cc:966] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inStatefulPartitionedCall/EfficientNetB0_FineTuned_1/efficientnetb0_1/block2b_drop_1/stateless_dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# I0000 00:00:1760636475.855769     106 cuda_dnn.cc:529] Loaded cuDNN version 90300
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 50s 127ms/step - accuracy: 0.6951 - loss: 0.8067 - val_accuracy: 0.9403 - val_loss: 0.2477 - learning_rate: 0.0010
# Epoch 2/10
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 20s 82ms/step - accuracy: 0.9274 - loss: 0.2388 - val_accuracy: 0.9537 - val_loss: 0.1592 - learning_rate: 0.0010
# Epoch 3/10
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 20s 83ms/step - accuracy: 0.9406 - loss: 0.1821 - val_accuracy: 0.9640 - val_loss: 0.1280 - learning_rate: 0.0010
# Epoch 4/10
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 21s 85ms/step - accuracy: 0.9590 - loss: 0.1415 - val_accuracy: 0.9738 - val_loss: 0.0968 - learning_rate: 0.0010
# Epoch 5/10
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 21s 88ms/step - accuracy: 0.9641 - loss: 0.1204 - val_accuracy: 0.9727 - val_loss: 0.0862 - learning_rate: 0.0010
# Epoch 6/10
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 21s 88ms/step - accuracy: 0.9605 - loss: 0.1166 - val_accuracy: 0.9799 - val_loss: 0.0727 - learning_rate: 0.0010
# Epoch 7/10
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 21s 88ms/step - accuracy: 0.9712 - loss: 0.0998 - val_accuracy: 0.9825 - val_loss: 0.0653 - learning_rate: 0.0010
# Epoch 8/10
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 21s 88ms/step - accuracy: 0.9715 - loss: 0.0938 - val_accuracy: 0.9789 - val_loss: 0.0630 - learning_rate: 0.0010
# Epoch 9/10
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 21s 87ms/step - accuracy: 0.9704 - loss: 0.0948 - val_accuracy: 0.9774 - val_loss: 0.0644 - learning_rate: 0.0010
# Epoch 10/10
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 21s 87ms/step - accuracy: 0.9725 - loss: 0.0854 - val_accuracy: 0.9810 - val_loss: 0.0592 - learning_rate: 0.0010
#
# --- Stage 2: Fine-Tuning Body ---
# Epoch 10/25
# E0000 00:00:1760636715.751805      37 meta_optimizer.cc:966] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inStatefulPartitionedCall/EfficientNetB0_FineTuned_1/efficientnetb0_1/block2b_drop_1/stateless_dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 49s 115ms/step - accuracy: 0.8693 - loss: 0.3592 - val_accuracy: 0.9758 - val_loss: 0.0797
# Epoch 11/25
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 24s 98ms/step - accuracy: 0.9384 - loss: 0.1901 - val_accuracy: 0.9763 - val_loss: 0.0730
# Epoch 12/25
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 23s 94ms/step - accuracy: 0.9506 - loss: 0.1563 - val_accuracy: 0.9799 - val_loss: 0.0635
# Epoch 13/25
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 23s 94ms/step - accuracy: 0.9495 - loss: 0.1368 - val_accuracy: 0.9851 - val_loss: 0.0515
# Epoch 14/25
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 23s 94ms/step - accuracy: 0.9651 - loss: 0.1067 - val_accuracy: 0.9856 - val_loss: 0.0448
# Epoch 15/25
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 23s 95ms/step - accuracy: 0.9733 - loss: 0.0894 - val_accuracy: 0.9866 - val_loss: 0.0390
# Epoch 16/25
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 23s 95ms/step - accuracy: 0.9720 - loss: 0.0886 - val_accuracy: 0.9887 - val_loss: 0.0339
# Epoch 17/25
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 23s 94ms/step - accuracy: 0.9754 - loss: 0.0728 - val_accuracy: 0.9913 - val_loss: 0.0312
# Epoch 18/25
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 23s 94ms/step - accuracy: 0.9787 - loss: 0.0628 - val_accuracy: 0.9913 - val_loss: 0.0276
# Epoch 19/25
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 23s 95ms/step - accuracy: 0.9810 - loss: 0.0550 - val_accuracy: 0.9918 - val_loss: 0.0255
# Epoch 20/25
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 23s 95ms/step - accuracy: 0.9786 - loss: 0.0597 - val_accuracy: 0.9938 - val_loss: 0.0230
# Epoch 21/25
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 23s 94ms/step - accuracy: 0.9814 - loss: 0.0510 - val_accuracy: 0.9943 - val_loss: 0.0200
# Epoch 22/25
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 23s 94ms/step - accuracy: 0.9829 - loss: 0.0518 - val_accuracy: 0.9949 - val_loss: 0.0195
# Epoch 23/25
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 23s 94ms/step - accuracy: 0.9857 - loss: 0.0449 - val_accuracy: 0.9949 - val_loss: 0.0184
# Epoch 24/25
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 23s 94ms/step - accuracy: 0.9849 - loss: 0.0473 - val_accuracy: 0.9949 - val_loss: 0.0174
# Epoch 25/25
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 23s 94ms/step - accuracy: 0.9899 - loss: 0.0299 - val_accuracy: 0.9959 - val_loss: 0.0162
# --- Model Evaluation on Test Set ---
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - accuracy: 0.9937 - loss: 0.0241
# ✅ Fine-Tuned EfficientNetB0 Test Accuracy: 99.59%
# ✅ Fine-Tuned EfficientNetB0 Test Loss: 0.0162
#
# --- Generating Classification Report and Confusion Matrix ---
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 10s 122ms/step
#
# Classification Report:
#                           precision    recall  f1-score   support
#
#       Apple___Apple_scab       1.00      0.99      0.99       504
#        Apple___Black_rot       1.00      1.00      1.00       497
# Apple___Cedar_apple_rust       1.00      1.00      1.00       440
#          Apple___healthy       0.99      1.00      0.99       502
#
#                 accuracy                           1.00      1943
#                macro avg       1.00      1.00      1.00      1943
#             weighted avg       1.00      1.00      1.00      1943
#
#
# Confusion Matrix:
