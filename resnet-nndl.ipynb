# %%
import tensorflow as tf
from tensorflow.keras import layers, models, applications
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
import matplotlib.pyplot as plt
import numpy as np
import os
import shutil
import seaborn as sns
from sklearn.metrics import classification_report, confusion_matrix

# 1. SETUP: CREATE FOCUSED "MULTI-PLANT" DATASET
# ==============================================================================
print("--- Setting up 'Apple, Corn, Potato' train, validation, and test datasets ---")

# --- Part A: Define all 11 classes ---
original_base_train_dir = '/kaggle/input/new-plant-diseases-dataset/New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)/train'
original_base_valid_dir = '/kaggle/input/new-plant-diseases-dataset/New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)/valid'

all_classes = [
    'Apple___Apple_scab', 'Apple___Black_rot', 'Apple___Cedar_apple_rust', 'Apple___healthy',
    'Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot', 'Corn_(maize)___Common_rust_',
    'Corn_(maize)___Northern_Leaf_Blight', 'Corn_(maize)___healthy',
    'Potato___Early_blight', 'Potato___Late_blight', 'Potato___healthy'
]
print(f"Total classes to load: {len(all_classes)}")

# --- Part B: Setup Train, Validation, and Test Dirs (using copytree) ---
temp_base_dir = '/kaggle/working/endsem_project_dataset'
train_dir = os.path.join(temp_base_dir, 'train')
test_dir = os.path.join(temp_base_dir, 'test') # We'll copy the 'valid' data here

os.makedirs(train_dir, exist_ok=True)
os.makedirs(test_dir, exist_ok=True)

print("Copying Train and Test (from Valid) files... This may take 1-2 minutes.")

for class_name in all_classes:
    # --- Train Data ---
    original_path = os.path.join(original_base_train_dir, class_name)
    new_path = os.path.join(train_dir, class_name)
    if not os.path.exists(new_path) and os.path.exists(original_path):
        shutil.copytree(original_path, new_path)

    # --- Test Data (from original_base_valid_dir) ---
    original_path = os.path.join(original_base_valid_dir, class_name)
    new_path = os.path.join(test_dir, class_name)
    if not os.path.exists(new_path) and os.path.exists(original_path):
        shutil.copytree(original_path, new_path)

print("Train and Test directories created via copy.")
print("----------------------------------------------------------------------")


# 2. DEFINE CONSTANTS AND HYPERPARAMETERS
# ==============================================================================
IMG_SIZE = 224
BATCH_SIZE = 32
VALIDATION_SPLIT = 0.20
RANDOM_SEED = 123
EPOCHS = 20 # We only have one training stage
LEARNING_RATE = 0.001
DROPOUT_RATE = 0.5

# 3. LOAD AND PREPROCESS DATA
# ==============================================================================
print("Loading and splitting dataset...")

# Create Training (80%) and Validation (20%) sets from the 'train_dir'
train_ds = tf.keras.utils.image_dataset_from_directory(
    train_dir,
    image_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    shuffle=True,
    seed=RANDOM_SEED,
    validation_split=VALIDATION_SPLIT,
    subset="training"
)

val_ds = tf.keras.utils.image_dataset_from_directory(
    train_dir,
    image_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    shuffle=False,
    seed=RANDOM_SEED,
    validation_split=VALIDATION_SPLIT,
    subset="validation"
)

# Create the final Test set from the separate 'test_dir'
test_ds = tf.keras.utils.image_dataset_from_directory(
    test_dir,
    image_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    shuffle=False
)

class_names = train_ds.class_names
NUM_CLASSES = len(class_names)
print(f"Found {NUM_CLASSES} classes: {class_names}")

AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.cache().prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)
test_ds = test_ds.cache().prefetch(buffer_size=AUTOTUNE)

data_augmentation = models.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1),
], name="data_augmentation")


# 4. DEFINE THE RESNET50V2 MODEL (FEATURE EXTRACTION ONLY)
# ==============================================================================
def build_resnet_model(num_classes):
    base_model = applications.ResNet50V2(
        include_top=False,
        weights='imagenet',
        input_shape=(IMG_SIZE, IMG_SIZE, 3),
        name="resnet50v2_base"
    )
    # The base model is NOT fine-tuned
    base_model.trainable = False 
    
    inputs = layers.Input(shape=(IMG_SIZE, IMG_SIZE, 3))
    x = data_augmentation(inputs)
    x = applications.resnet_v2.preprocess_input(x)
    x = base_model(x, training=False)
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dropout(DROPOUT_RATE)(x)
    outputs = layers.Dense(num_classes, activation="softmax")(x)
    
    model = models.Model(inputs, outputs, name="ResNet50V2_Baseline")
    return model

# 5. COMPILE AND TRAIN (ONE STAGE ONLY)
# ==============================================================================
resnet_model = build_resnet_model(NUM_CLASSES)
print("\n--- Baseline ResNet50V2 Summary (Base Frozen) ---")
resnet_model.summary()

early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
lr_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=2, min_lr=1e-6, verbose=1)

# --- Train the Classifier Head ---
resnet_model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=LEARNING_RATE),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

print("\n--- Training Baseline ResNet50V2 Model ---")
history = resnet_model.fit(
    train_ds,
    epochs=EPOCHS,
    validation_data=val_ds, # Validate on the 20% split
    callbacks=[early_stopping, lr_scheduler]
)

# 6. PLOT TRAINING & VALIDATION HISTORY
# ==============================================================================
def plot_history(history, model_name):
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']

    plt.style.use('seaborn-v0_8-whitegrid')
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(18, 6))

    ax1.plot(acc, 'o-', label='Train Accuracy')
    ax1.plot(val_acc, 'o--', label='Validation Accuracy')
    ax1.set_title(f'{model_name} Accuracy')
    ax1.set_ylabel('Accuracy')
    ax1.set_xlabel('Epoch')
    ax1.legend()

    ax2.plot(loss, 'o-', label='Train Loss')
    ax2.plot(val_loss, 'o--', label='Validation Loss')
    ax2.set_title(f'{model_name} Loss')
    ax2.set_ylabel('Loss')
    ax2.set_xlabel('Epoch')
    ax2.legend()
    plt.suptitle(f'{model_name} Performance', fontsize=16)
    plt.show()

plot_history(history, "Baseline ResNet50V2")


# 7. FINAL EVALUATION AND CLASSIFICATION METRICS (on the REAL test set)
# ==============================================================================
print("\n--- Model Evaluation on Test Set (from 'valid' folder) ---")

loss, accuracy = resnet_model.evaluate(test_ds, verbose=1)
print(f"✅ Baseline ResNet50V2 Test Accuracy: {accuracy*100:.2f}%")
print(f"✅ Baseline ResNet50V2 Test Loss: {loss:.4f}")

print("\n--- Generating Classification Report and Confusion Matrix ---")
y_true = np.concatenate([y for x, y in test_ds], axis=0)
y_pred_probs = resnet_model.predict(test_ds)
y_pred = np.argmax(y_pred_probs, axis=1)

labels = np.arange(len(class_names))
print("\nClassification Report:")
print(classification_report(y_true, y_pred, target_names=class_names, labels=labels, zero_division=0))

print("\nConfusion Matrix:")
cm = confusion_matrix(y_true, y_pred, labels=labels)
plt.figure(figsize=(12, 10))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=class_names, yticklabels=class_names)
plt.title('Confusion Matrix for Baseline ResNet50V2 (on Test Set)')
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.show()
# Out:
# 2025-11-09 18:10:30.184840: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1762711830.373895      48 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1762711830.427498      48 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# --- Setting up 'Apple, Corn, Potato' train, validation, and test datasets ---
# Total classes to load: 11
# Copying Train and Test (from Valid) files... This may take 1-2 minutes.
# Train and Test directories created via copy.
# ----------------------------------------------------------------------
# Loading and splitting dataset...
# Found 20789 files belonging to 11 classes.
# Using 16632 files for training.
# I0000 00:00:1762712047.310544      48 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Found 20789 files belonging to 11 classes.
# Using 4157 files for validation.
# Found 5198 files belonging to 11 classes.
# Found 11 classes: ['Apple___Apple_scab', 'Apple___Black_rot', 'Apple___Cedar_apple_rust', 'Apple___healthy', 'Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot', 'Corn_(maize)___Common_rust_', 'Corn_(maize)___Northern_Leaf_Blight', 'Corn_(maize)___healthy', 'Potato___Early_blight', 'Potato___Late_blight', 'Potato___healthy']
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94668760/94668760 ━━━━━━━━━━━━━━━━━━━━ 4s 0us/step
#
# --- Baseline ResNet50V2 Summary (Base Frozen) ---
# Model: "ResNet50V2_Baseline"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ data_augmentation (Sequential)  │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ true_divide (TrueDivide)        │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ subtract (Subtract)             │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ resnet50v2_base (Functional)    │ (None, 7, 7, 2048)     │    23,564,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 2048)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 11)             │        22,539 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 23,587,339 (89.98 MB)
#  Trainable params: 22,539 (88.04 KB)
#  Non-trainable params: 23,564,800 (89.89 MB)
# --- Training Baseline ResNet50V2 Model ---
# Epoch 1/20
# I0000 00:00:1762712063.670533     113 cuda_dnn.cc:529] Loaded cuDNN version 90300
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 68s 113ms/step - accuracy: 0.7180 - loss: 0.8519 - val_accuracy: 0.9603 - val_loss: 0.1507 - learning_rate: 0.0010
# Epoch 2/20
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 43s 82ms/step - accuracy: 0.9310 - loss: 0.2040 - val_accuracy: 0.9644 - val_loss: 0.1257 - learning_rate: 0.0010
# Epoch 3/20
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 43s 82ms/step - accuracy: 0.9427 - loss: 0.1652 - val_accuracy: 0.9716 - val_loss: 0.0982 - learning_rate: 0.0010
# Epoch 4/20
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 43s 82ms/step - accuracy: 0.9491 - loss: 0.1496 - val_accuracy: 0.9796 - val_loss: 0.0750 - learning_rate: 0.0010
# Epoch 5/20
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 43s 82ms/step - accuracy: 0.9534 - loss: 0.1319 - val_accuracy: 0.9699 - val_loss: 0.0943 - learning_rate: 0.0010
# Epoch 6/20
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.9538 - loss: 0.1307
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 43s 82ms/step - accuracy: 0.9538 - loss: 0.1307 - val_accuracy: 0.9726 - val_loss: 0.0841 - learning_rate: 0.0010
# Epoch 7/20
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 43s 82ms/step - accuracy: 0.9568 - loss: 0.1169 - val_accuracy: 0.9699 - val_loss: 0.0890 - learning_rate: 2.0000e-04
# Epoch 8/20
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 43s 82ms/step - accuracy: 0.9587 - loss: 0.1190 - val_accuracy: 0.9793 - val_loss: 0.0706 - learning_rate: 2.0000e-04
# Epoch 9/20
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 42s 81ms/step - accuracy: 0.9572 - loss: 0.1134 - val_accuracy: 0.9767 - val_loss: 0.0705 - learning_rate: 2.0000e-04
# Epoch 10/20
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.9607 - loss: 0.1095
# Epoch 10: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 41s 79ms/step - accuracy: 0.9607 - loss: 0.1095 - val_accuracy: 0.9774 - val_loss: 0.0758 - learning_rate: 2.0000e-04
# Epoch 11/20
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 41s 79ms/step - accuracy: 0.9638 - loss: 0.1018 - val_accuracy: 0.9781 - val_loss: 0.0722 - learning_rate: 4.0000e-05
# Epoch 12/20
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.9630 - loss: 0.1043
# Epoch 12: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 42s 81ms/step - accuracy: 0.9630 - loss: 0.1043 - val_accuracy: 0.9776 - val_loss: 0.0717 - learning_rate: 4.0000e-05
# Epoch 13/20
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 43s 82ms/step - accuracy: 0.9635 - loss: 0.1038 - val_accuracy: 0.9779 - val_loss: 0.0712 - learning_rate: 8.0000e-06
# Epoch 14/20
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 43s 82ms/step - accuracy: 0.9614 - loss: 0.1045 - val_accuracy: 0.9803 - val_loss: 0.0697 - learning_rate: 8.0000e-06
# Epoch 15/20
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 43s 82ms/step - accuracy: 0.9588 - loss: 0.1085 - val_accuracy: 0.9793 - val_loss: 0.0701 - learning_rate: 8.0000e-06
# Epoch 16/20
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.9611 - loss: 0.1068
# Epoch 16: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 43s 82ms/step - accuracy: 0.9611 - loss: 0.1068 - val_accuracy: 0.9796 - val_loss: 0.0699 - learning_rate: 8.0000e-06
# Epoch 17/20
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 43s 82ms/step - accuracy: 0.9639 - loss: 0.1025 - val_accuracy: 0.9793 - val_loss: 0.0697 - learning_rate: 1.6000e-06
# Epoch 18/20
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 43s 82ms/step - accuracy: 0.9583 - loss: 0.1169 - val_accuracy: 0.9796 - val_loss: 0.0693 - learning_rate: 1.6000e-06
# Epoch 19/20
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 43s 83ms/step - accuracy: 0.9637 - loss: 0.1038 - val_accuracy: 0.9793 - val_loss: 0.0692 - learning_rate: 1.6000e-06
# Epoch 20/20
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 43s 82ms/step - accuracy: 0.9638 - loss: 0.1035 - val_accuracy: 0.9791 - val_loss: 0.0694 - learning_rate: 1.6000e-06
# --- Model Evaluation on Test Set (from 'valid' folder) ---
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 11s 68ms/step - accuracy: 0.9717 - loss: 0.0846
# ✅ Baseline ResNet50V2 Test Accuracy: 97.36%
# ✅ Baseline ResNet50V2 Test Loss: 0.0752
#
# --- Generating Classification Report and Confusion Matrix ---
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 13s 70ms/step
#
# Classification Report:
#                                                     precision    recall  f1-score   support
#
#                                 Apple___Apple_scab       0.99      0.96      0.97       504
#                                  Apple___Black_rot       0.99      0.98      0.99       497
#                           Apple___Cedar_apple_rust       1.00      0.99      0.99       440
#                                    Apple___healthy       0.96      0.99      0.97       502
# Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot       0.94      0.89      0.91       410
#                        Corn_(maize)___Common_rust_       1.00      1.00      1.00       477
#                Corn_(maize)___Northern_Leaf_Blight       0.91      0.95      0.93       477
#                             Corn_(maize)___healthy       1.00      1.00      1.00       465
#                              Potato___Early_blight       0.99      0.99      0.99       485
#                               Potato___Late_blight       0.99      0.97      0.98       485
#                                   Potato___healthy       0.97      0.99      0.98       456
#
#                                           accuracy                           0.97      5198
#                                          macro avg       0.97      0.97      0.97      5198
#                                       weighted avg       0.97      0.97      0.97      5198
#
#
# Confusion Matrix:
